# %%
import os
import sys
import pandas as pd
import numpy as np
import scipy

sys.path.append(os.path.abspath('..'))

import warnings
from typing import TypedDict, List, Tuple, Dict
from pydantic import BaseModel, Field
from dotenv import load_dotenv

from openai import OpenAI

# %%
load_dotenv()
warnings.filterwarnings("ignore")

# %%
llm = OpenAI(
	api_key = os.getenv("OPENAI_API_KEY")
)
# llm = ChatOpenAI(model="gemini-2.0-flash-exp", api_key=os.getenv("GEMINI_API_KEY"), base_url=os.getenv("GEMINI_BASE_URL"))
# llm = ChatOpenAI(model="gemini-exp-1206", api_key=os.getenv("GEMINI_API_KEY"), base_url=os.getenv("GEMINI_BASE_URL"))

# %%
class Code(BaseModel):
    code: str = Field(..., title="Code", description="Đoạn mã Python được sinh ra.")
    explanation: str = Field(..., title="Explanation", description="Giải thích cách tiếp cận.")

class Review(BaseModel):
    should_continue: bool = Field(..., title="Should Continue", description="True nếu cần cập nhật lại, False nếu dừng.")
    review: str = Field(..., title="Review", description="Phản hồi từ Reviewer.")

# %%
system_prompt = "Bạn là cleaner." # Placeholder
data_description = "Dữ liệu là một bảng dữ liệu với các cột là: 'doanh số', 'lợi nhuận', 'chi phí'." # Placeholder

response = llm.beta.chat.completions.parse(
	model="gpt-4o-mini-2024-07-18",
	messages=[
		{"role": "system", "content": system_prompt},
		{"role": "user", "content": data_description},
	],
	seed=0,
	temperature=0.5,
	response_format=Code,
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 3
#       1 system_prompt = "Bạn là cleaner." # Placeholder
# ----> 3 response = llm.beta.chat.completions.parse(
#       4 	model="gpt-4o-mini-2024-07-18",
#       5 	messages=[
#       6 		{"role": "system", "content": system_prompt},
#       7 		{"role": "user", "content": "Dữ liệu "},
#       8 	],
#       9 	seed=0,
#      10 	temperature=0.5,
#      11 	response_format=Code,
#      12 )
#
# ...

# %%
print(respon.choices[0].message.parsed.explanation)
# Out:
# Đoạn mã trên định nghĩa một hàm `is_prime(n)` để kiểm tra xem một số nguyên `n` có phải là số nguyên tố hay không. Đầu tiên, nó kiểm tra nếu `n` nhỏ hơn hoặc bằng 1 thì trả về `False` vì các số này không phải là số nguyên tố. Sau đó, nó sử dụng một vòng lặp từ 2 đến căn bậc hai của `n` để kiểm tra xem có số nào chia hết cho `n` hay không. Nếu tìm thấy một số chia hết, hàm trả về `False`. Nếu không tìm thấy số nào chia hết, nó trả về `True`, xác nhận rằng `n` là số nguyên tố.
