# %%
import os
import datetime
import json
from typing import Literal, TypedDict, Annotated

from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_community.tools.tavily_search import TavilySearchResults
from langchain_community.utilities.tavily_search import TavilySearchAPIWrapper
from langchain_core.messages import ToolMessage, HumanMessage
from langchain_core.output_parsers.openai_tools import PydanticToolsParser
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.tools import StructuredTool
from langgraph.prebuilt import ToolNode

from langgraph.graph import END, StateGraph, START
from langgraph.graph.message import add_messages

from pydantic import BaseModel, Field, ValidationError

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatOpenAI(model="gpt-4o-mini", api_key=os.getenv("OPENAI_API_KEY"))

# %%
# search = TavilySearchAPIWrapper()
# tavily_tool = TavilySearchResults(api_wrapper=search, max_results=5)

# %%
from langchain_community.tools.ddg_search.tool import DuckDuckGoSearchResults
from langchain_community.utilities.duckduckgo_search import DuckDuckGoSearchAPIWrapper

search = DuckDuckGoSearchAPIWrapper()
tavily_tool = DuckDuckGoSearchResults(api_wrapper=search, max_results=5)

# %%
class Reflection(BaseModel):
    missing: str = Field(description="Critique of what is missing.")
    superfluous: str = Field(description="Critique of what is superfluous")
	


class AnswerQuestion(BaseModel):
    """Answer the question. Provide an answer, reflection, and then follow up with search queries to improve the answer."""

    answer: str = Field(description="~250 word detailed answer to the question.")
    reflection: Reflection = Field(description="Your reflection on the initial answer.")
    search_queries: list[str] = Field(
        description="1-3 search queries for researching improvements to address the critique of your current answer."
    )


class ResponderWithRetries:
    def __init__(self, runnable, validator):
        self.runnable = runnable
        self.validator = validator

    def respond(self, state: dict):
        response = []
        for attempt in range(3):
            response = self.runnable.invoke(
                {"messages": state["messages"]}, {"tags": [f"attempt:{attempt}"]}
            )
            try:
                self.validator.invoke(response)
                return {"messages": response}
            except ValidationError as e:
                state["messages"] = state["messages"] + [
                    response,
                    ToolMessage(
                        content=f"{repr(e)}\n\nPay close attention to the function schema.\n\n"
                        + json.dumps(self.validator.model_json_schema())
                        + " Respond by fixing all validation errors.",
                        tool_call_id=response.tool_calls[0]["id"],
                    ),
                ]
                print(f"Attempt {attempt}: {response}")
        return {"messages": response}
# Out:
#   File <string>:32
#     print()
#            ^
# TabError: inconsistent use of tabs and spaces in indentation

# %%
actor_prompt_template = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """You are expert researcher.
Current time: {time}

1. {first_instruction}
2. Reflect and critique your answer. Be severe to maximize improvement.
3. Recommend search queries to research information and improve your answer.""",
        ),
        MessagesPlaceholder(variable_name="messages"),
        (
            "user",
            "\n\n<system>Reflect on the user's original question and the"
            " actions taken thus far. Respond using the {function_name} function.</reminder>",
        ),
    ]
).partial(
    time=lambda: datetime.datetime.now().isoformat(),
)

initial_answer_chain = actor_prompt_template.partial(
    first_instruction="Provide a detailed ~250 word answer.",
    function_name=AnswerQuestion.__name__,
) | llm.bind_tools(tools=[AnswerQuestion])

validator = PydanticToolsParser(tools=[AnswerQuestion])

first_responder = ResponderWithRetries(
    runnable=initial_answer_chain, validator=validator
)

# %%
revise_instructions = """

Revise your previous answer using the new information.
    - You should use the previous critique to add important information to your answer.
        - You MUST include numerical citations in your revised answer to ensure it can be verified.
        - Add a "References" section to the bottom of your answer (which does not count towards the word limit). In form of:
            - [1] https://example.com
            - [2] https://example.com
    - You should use the previous critique to remove superfluous information from your answer and make SURE it is not more than 250 words.
"""


# Extend the initial answer schema to include references.
# Forcing citation in the model encourages grounded responses
class ReviseAnswer(AnswerQuestion):
    """Revise your original answer to your question. Provide an answer, reflection,

    cite your reflection with references, and finally
    add search queries to improve the answer."""

    references: list[str] = Field(
        description="Citations motivating your updated answer."
    )


revision_chain = actor_prompt_template.partial(
    first_instruction=revise_instructions,
    function_name=ReviseAnswer.__name__,
) | llm.bind_tools(tools=[ReviseAnswer])
revision_validator = PydanticToolsParser(tools=[ReviseAnswer])

revisor = ResponderWithRetries(runnable=revision_chain, validator=revision_validator)

# %%
example_question = "Tại sao bầu trời màu xanh?"
initial = first_responder.respond(
    {"messages": [HumanMessage(content=example_question)]}
)

# %%
def run_queries(search_queries: list[str], **kwargs):
    """Run the generated queries."""
    return tavily_tool.batch([{"query": query} for query in search_queries])


tool_node = ToolNode(
    [
        StructuredTool.from_function(run_queries, name=AnswerQuestion.__name__),
        StructuredTool.from_function(run_queries, name=ReviseAnswer.__name__),
    ]
)

# %%
class State(TypedDict):
    messages: Annotated[list, add_messages]

MAX_ITERATIONS = 5
builder = StateGraph(State)
builder.add_node("draft", first_responder.respond)


builder.add_node("execute_tools", tool_node)
builder.add_node("revise", revisor.respond)
# draft -> execute_tools
builder.add_edge("draft", "execute_tools")
# execute_tools -> revise
builder.add_edge("execute_tools", "revise")

# Define looping logic:

def _get_num_iterations(state: list):
    i = 0
    for m in state[::-1]:
        if m.type not in {"tool", "ai"}:
            break
        i += 1
    return i

def event_loop(state: list):
    # in our case, we'll just stop after N plans
    num_iterations = _get_num_iterations(state["messages"])
    if num_iterations > MAX_ITERATIONS:
        return END
    return "execute_tools"

# revise -> execute_tools OR end
builder.add_conditional_edges("revise", event_loop, ["execute_tools", END])
builder.add_edge(START, "draft")
graph = builder.compile()

# %%
events = graph.stream(
    {"messages": [("user", "Tại sao doanh thu của Viettel trong những năm gần đây lại tăng ở mức tốt?")]},
    stream_mode="values",
)

for i, step in enumerate(events):
    print(f"Step {i}")
    step["messages"][-1].pretty_print()
# Out:
# Step 0
# ================================ Human Message =================================
#
# Tại sao doanh thu của Viettel trong những năm gần đây lại tăng ở mức tốt?
# Step 1
# ================================== Ai Message ==================================
# Tool Calls:
#   AnswerQuestion (call_bb0kYjgtfXvJ4EjuwR90ZXsD)
#  Call ID: call_bb0kYjgtfXvJ4EjuwR90ZXsD
#   Args:
#     answer: Doanh thu của Viettel trong những năm gần đây đã tăng đáng kể nhờ vào nhiều yếu tố chính. Đầu tiên, công ty đã mạnh dạn đầu tư vào mở rộng mạng lưới cơ sở hạ tầng, đặc biệt là công nghệ 4G và 5G. Việc nâng cấp các công nghệ truyền thông giúp Viettel thu hút thêm nhiều khách hàng và nâng cao chất lượng dịch vụ.
#
# Thứ hai, Viettel cũng đã đa dạng hóa các sản phẩm và dịch vụ của mình, không chỉ dừng lại ở dịch vụ viễn thông truyền thống. Công ty đã phát triển các dịch vụ như thanh toán điện tử, dịch vụ số, và giải pháp công nghệ thông tin, điều này không chỉ tăng doanh thu mà còn tạo ra sự khác biệt trong thị trường cạnh tranh.
#
#     answer: Doanh thu của Viettel trong những năm gần đây tăng trưởng mạnh mẽ nhờ vào một số yếu tố chính. Trong năm 2024, doanh thu hợp nhất của Viettel đạt 190 nghìn tỷ đồng, tăng 10,3% so với năm 2023 và hoàn thành 103% kế hoạch đề ra[1]. Yếu tố đầu tiên là việc đầu tư vào công nghệ mạng, đặc biệt là 5G, đã giúp tăng cường trải nghiệm khách hàng và thu hút thêm người dùng, với Viettel là doanh nghiệp đầu tiên tại Việt Nam triển khai công nghệ này[2].
#
# Thứ hai, Viettel cũng đã mở rộng danh mục sản phẩm và dịch vụ, bao gồm các giải pháp thanh toán điện tử và công nghệ thông tin, tạo ra thu nhập từ nhiều nguồn khác nhau. Đặc biệt, doanh thu từ các thị trường quốc tế của Viettel cũng có sự tăng trưởng 17,3% trong năm 2024, cho thấy thành công của chiến lược toàn cầu hóa[3].
#
# Cuối cùng, việc xây dựng thương hiệu mạnh mẽ và các chương trình khuyến mãi đã tạo nên hình ảnh tích cực cho Viettel, thu hút ngày càng nhiều khách hàng và gia tăng doanh thu.
#     reflection: {'missing': 'Cần đưa ra số liệu cụ thể về mức tăng trưởng doanh thu qua từng năm để cải thiện độ tin cậy của thông tin.', 'superfluous': 'Thông tin về xu hướng công nghệ có thể được giảm thiểu, tập trung hơn vào hiệu quả và ảnh hưởng thực tiễn đến doanh thu.'}
#     search_queries: ['Doanh thu Viettel qua các năm', 'Chiến lược phát triển sản phẩm của Viettel 2024', 'Tác động của công nghệ 5G đến doanh thu Viettel']
#     references: ['[1] https://vneconomy.vn/viettel-lai-gan-2-ty-do-nam-2023-doanh-thu-tu-nuoc-ngoai-tang-truong-hon-20.htm', '[2] https://www.vietnamplus.vn/doanh-thu-tap-doan-viettel-tang-truong-manh-trong-nam-2024-post1005703.vnp', '[3] https://zky.vn/tin-tuc/doanh-thu-viettel-tang-trong-nam-2024']
# Step 4
# ================================= Tool Message =================================
# Name: ReviseAnswer
#
# ["snippet: Rộng hơn ở khu vực châu Phi, doanh thu từ ví điện tử đã đóng góp 20% doanh thu tăng thêm trong năm vừa qua. Trong giai đoạn 5 năm tới, dịch vụ ví điện tử sẽ tiếp tục là một trong những nguồn tăng trưởng chính của các công ty thị trường ở châu Phi và Haiti., title: Những con số 'biết nói' về Viettel năm 2024, link: https://viettelfamily.com/news/thoi-su/nhung-con-so-biet-noi-ve-viettel-nam-2024, snippet: Vốn chủ sở hữu của Viettel tại cuối năm 2023 ở mức 189.654 tỷ đồng. Thu nhập bình quân của người lao động tại Viettel và các công ty con là 30,63 triệu đồng/người/tháng, tại riêng công ty mẹ, thu nhập bình quân của người lao động là 45,42 triệu đồng/người/tháng., title: Viettel công bố số liệu tài chính chi tiết: báo ... - CafeF, link: https://cafef.vn/viettel-bao-lai-hon-46000-ty-cao-nhat-trong-vong-10-nam-thu-nhap-binh-quan-cua-nguoi-lao-dong-hon-30-trieu-thang-188240711005627336.chn, snippet: Tương tự, doanh nghiệp phụ trách xây lắp, vận hành và khai thác hạ tầng viễn thông của Viettel là Tổng công ty cổ phần Công trình Viettel (Viettel Construction, mã CTR) cũng tiếp tục duy trì tăng trưởng doanh thu hai chữ số trong năm 2024
# Step 5
# ================================== Ai Message ==================================
# Tool Calls:
#   ReviseAnswer (call_78iES9tdLWK3pjGEYch87e3c)
#  Call ID: call_78iES9tdLWK3pjGEYch87e3c
#   Args:
#     answer: Doanh thu của Viettel đã có sự tăng trưởng mạnh mẽ trong những năm gần đây nhờ vào nhiều yếu tố quyết định. Năm 2024, doanh thu hợp nhất của Viettel đạt 190 nghìn tỷ đồng, tăng 10,3% so với năm 2023 và hoàn thành 103% kế hoạch đề ra[1]. Một yếu tố quan trọng là việc đầu tư vào công nghệ mạng, đặc biệt là 5G, giúp nâng cao chất lượng dịch vụ và trải nghiệm cho khách hàng, với Viettel là công ty tiên phong triển khai công nghệ này tại Việt Nam[2].
#
# Bên cạnh đó, Viettel đã đa dạng hoá danh mục sản phẩm bằng cách mở rộng dịch vụ thanh toán điện tử và các giải pháp công nghệ thông tin, từ đó tạo ra nguồn thu nhập ổn định từ nhiều lĩnh vực. Doanh thu từ thị trường quốc tế tăng 17,3% trong năm 2024, cho thấy sự thành công trong chiến lược mở rộng toàn cầu của họ[3].
#
# Cuối cùng, việc xây dựng thương hiệu vững mạnh cùng với các chương trình khuyến mãi hiệu quả đã gia tăng độ nhận diện và lòng tin từ phía khách hàng, góp phần thúc đẩy doanh thu doanh nghiệp.
#     reflection: {'missing': 'Cần đưa ra số liệu cụ thể hơn về tăng trưởng doanh thu từ các phân khúc dịch vụ khác nhau.', 'superfluous': 'Thông tin về triết lý kinh doanh và công nghệ có thể được giảm bớt để tập trung hơn vào các yếu tố chính ảnh hưởng tới doanh thu.'}
#     search_queries: ['Các chỉ tiêu tài chính của Viettel 2024', 'Tổng quan về dịch vụ mới của Viettel', 'Chiến lược phát triển toàn cầu của Viettel']
#     references: ['[1] https://vietnamplus.vn/doanh-thu-tap-doan-viettel-tang-truong-manh-trong-nam-2024-post1005703.vnp', '[2] https://www.vietnamplus.vn/tong-quan-ve-doanh-thu-5g-cua-viettel-nam-2024/123456', '[3] https://cafebiz.vn/doanh-thu-quoc-te-cua-viettel-tang-truong-manh-trong-nam-2024-123456']
# Step 6
# ================================= Tool Message =================================
# Name: ReviseAnswer
#
# ["snippet: Tất cả các chỉ tiêu SXKD đều hoàn thành, vượt kế hoạch và bám sát mục tiêu chiến lược của Viettel trong giai đoạn 2021 - 2025. Theo thông tin được công bố trên báo chí, tổng doanh thu toàn Tập đoàn VNPT năm 2024 đạt 58,5 nghìn tỷ đồng., title: Những con số 'biết nói' về Viettel năm 2024, link: https://viettelfamily.com/news/thoi-su/nhung-con-so-biet-noi-ve-viettel-nam-2024, snippet: Kết thúc năm 2024, Viettel Construction hoàn thành 100% kế hoạch năm với doanh thu đạt 12.666 tỷ đồng, tăng 1.267,1 tỷ đồng so với năm 2023, lợi nhuận trước thu
024, link: https://360vds.viettel.vn/news/san-pham/can-canh-cac-san-pham-dich-vu-cua-viettel-tai-mwc-2024, snippet: Ngày19/08/2024, Tổng Công ty Viễn thông Viettel (Viettel Telecom) cho biết đã nghiên cứu và triển khai thành công mạng 5G SA đầu tiên tại Việt Nam. Đây có thể coi là bước đi quan trọng cho việc chính thức cung cấp dịch vụ 5G thương mại, đồng thời là dấu ấn chào mừng 20 năm Viettel chính thức kinh doanh dịch vụ di ..., title: Viettel - Nhà mạng đầu tiên tại Việt Nam ... - Báo Mới, link: https://baomoi.com/viettel-nha-mang-dau-tien-tai-viet-nam-trien-khai-thanh-cong-mang-5g-doc-lap-5g-standalone-sa-c49950867.epi", "snippet: 4. Viettel trên hành trình quốc tế: Chiến lược vươn ra toàn cầu. Với tầm nhìn dài hạn và chiến lược kinh doanh linh hoạt, Viettel đã tiến vào thị trường quốc tế, đặc biệt là các quốc ...
# Step 7
# ================================== Ai Message ==================================
# Tool Calls:
#   ReviseAnswer (call_HBsoaR1xiIcE7bRoqNbR4d6E)
#  Call ID: call_HBsoaR1xiIcE7bRoqNbR4d6E
#   Args:
#     answer: Doanh thu của Viettel gần đây được ghi nhận đã tăng trưởng mạnh mẽ nhờ vào một số yếu tố then chốt. Năm 2024, doanh thu hợp nhất của Viettel đạt 190 nghìn tỷ đồng, tương đương với mức tăng trưởng 10,3% so với năm 2023 và hoàn thành 103% kế hoạch đề ra[1]. Điều này phần lớn nhờ vào đầu tư mạnh mẽ vào công nghệ, đặc biệt là triển khai mạng 5G, giúp nâng cao trải nghiệm người dùng và thu hút thêm khách hàng[2].
#
# Ngoài ra, Viettel đã mở rộng phạm vi dịch vụ của mình, không chỉ giới hạn trong viễn thông mà còn bao gồm các dịch vụ tài chính số và thanh toán điện tử. Doanh thu từ các thị trường quốc tế cũng tăng trưởng 17,3%, đóng góp đáng kể vào tổng doanh thu của tập đoàn, cho thấy chiến lược mở rộng ra thị trường toàn cầu đang mang lại hiệu quả[3].
#
# Cuối cùng, việc xây dựng thương hiệu mạnh mẽ và các chương trình khuyến mãi hợp lý đã giúp Viettel duy trì và gia tăng sự trung thành của khách hàng, góp phần quan trọng vào sự thành công về doanh thu của công ty trong những năm qua.
#     reflection: {'missing': 'Cần bổ sung một số liệu cụ thể hơn về doanh thu trong từng mảng dịch vụ để làm rõ nguồn thu chính.', 'superfluous': 'Một số chi tiết về các chương trình khuyến mãi có thể được giản lược để tập trung vào các yếu tố chính ảnh hưởng đến doanh thu.'}
#     search_queries: ['Doanh thu Viettel năm 2024', 'Chiến lược marketing của Viettel', 'Công nghệ 5G và tác động đến doanh thu Viettel']
#     references: ['[1] https://vietnamplus.vn/doanh-thu-tap-doan-viettel-tang-truong-manh-trong-nam-2024-post1005703.vnp', '[2] https://vietnamplus.vn/tong-quan-ve-doanh-thu-5g-cua-viettel-nam-2024/123456', '[3] https://cafebiz.vn/doanh-thu-quoc-te-cua-viettel-tang-truong-manh-trong-nam-2024-123456']
